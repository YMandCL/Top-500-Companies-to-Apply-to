# %%
import os
os.getcwd()
os.chdir("C:\\Users\\Watson Turbo\Desktop\S&P500")

# %%
#Import standard Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = 'https://raw.githubusercontent.com/hevangel/stock_scraper/master/data_finviz/finviz_2020-04-02.csv'
sp = pd.read_csv(url)

# %%
sp.head()
# Out:
#   Ticker        Date  No.                              Company  \
# 0      A  2020-04-02    1           Agilent Technologies, Inc.
# 1     AA  2020-04-02    2                    Alcoa Corporation
# 2   AAAU  2020-04-02    3         Perth Mint Physical Gold ETF
# 3   AACG  2020-04-02    4                ATA Creativity Global
# 4   AADR  2020-04-02    5  AdvisorShares Dorsey Wright ADR ETF
#
#             Sector                         Industry Country Market Cap    P/E  \
# 0       Healthcare  Medical Laboratories & Research     USA     23.27B  29.83
# 1  Basic Materials                         Aluminum     USA      1.18B      -
# 2        Financial             Exchange Traded Fund     USA          -      -
# 3         Services    Education & Training Services   China     27.14M      -
# 4        Financial             Exchange Traded Fund     USA          -      -
#
#    Price  Change    Volume
# 0  72.29   4.89%   1811028
# 1   6.08  -2.72%  10251655
# 2  16.18   1.95%     99190
# ...

# %%
sp.shape
# Out:
# (3100, 12)

# %% [markdown]
# <b> Shouldn't this be 500 rows instead of 3100?

# %%
sp.columns
# Out:
# Index(['Ticker', 'Date', 'No.', 'Company', 'Sector', 'Industry', 'Country',
#        'Market Cap', 'P/E', 'Price', 'Change', 'Volume'],
#       dtype='object')

# %%
#Check for nulls
display(sp.isnull().any())
#List null instances
#copper[copper['Low'].isnull()]
# Out:
# Ticker        False
# Date          False
# No.           False
# Company       False
# Sector        False
# Industry      False
# Country       False
# Market Cap    False
# P/E           False
# Price         False
# Change        False
# Volume        False
# dtype: bool

# %%
sp500 = sp.rename(columns = {'Ticker':'Symbol'})

# %% [markdown]
# <b>P/E and Market Cap are missing in some instances. This Null display is wrong.

# %%
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'

# %%
test = pd.read_html(url)

# %%
df = test[0]

# %%
df.head()
# Out:
#   Symbol             Security SEC filings             GICS Sector  \
# 0    MMM           3M Company     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV          AbbVie Inc.     reports             Health Care
# 3   ABMD          ABIOMED Inc     reports             Health Care
# 4    ACN        Accenture plc     reports  Information Technology
#
#                 GICS Sub Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota       1976-08-09
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#          CIK      Founded
# 0    66740.0         1902
# 1     1800.0         1888
# 2  1551152.0  2013 (1888)
# ...

# %%
df.sort_values('Symbol')
# Out:
#     Symbol                  Security SEC filings             GICS Sector  \
# 11       A  Agilent Technologies Inc     reports             Health Care
# 30     AAL   American Airlines Group     reports             Industrials
# 8      AAP        Advance Auto Parts     reports  Consumer Discretionary
# 49    AAPL                Apple Inc.     reports  Information Technology
# 2     ABBV               AbbVie Inc.     reports             Health Care
# ..     ...                       ...         ...                     ...
# 503    ZBH    Zimmer Biomet Holdings     reports             Health Care
# 502   ZBRA        Zebra Technologies     reports  Information Technology
# 504   ZION             Zions Bancorp     reports              Financials
# 505    ZTS                    Zoetis     reports             Health Care
# 464    NaN                       NaN         NaN                     NaN
#
#                               GICS Sub Industry     Headquarters Location  \
# ...

# %% [markdown]
# ## Fortune 500

# %%
fortune_url ='https://raw.githubusercontent.com/rsilen18/fortune500-jupyter/master/fortune500.csv'

# %%
fortune = pd.read_csv(fortune_url)

# %%
fortune.head()
# Out:
#    Year  Rank           Company  Revenue (in millions) Profit (in millions)
# 0  1955     1    General Motors                 9823.5                  806
# 1  1955     2       Exxon Mobil                 5661.4                584.8
# 2  1955     3        U.S. Steel                 3250.4                195.4
# 3  1955     4  General Electric                 2959.1                212.6
# 4  1955     5            Esmark                 2510.8                 19.1

# %%
fortune.sort_values('Company')
# Out:
#        Year  Rank             Company  Revenue (in millions)  \
# 22302  1999   303                3Com                 5420.4
# 21954  1998   455                3Com                 3147.1
# 22793  2000   294                3Com                 5772.1
# 19995  1994   496                3Com                  617.2
# 23328  2001   329                3Com                 5391.5
# ...     ...   ...                 ...                    ...
# 1266   1957   267  Zenith Electronics                  141.5
# 2220   1959   221  Zenith Electronics                  180.6
# 13276  1981   277  Zenith Electronics                 1185.9
# 10217  1975   218  Zenith Electronics                  910.5
# 18463  1991   464     Zurn Industries                  610.6
#
#       Profit (in millions)
# 22302                 30.2
# 21954                  374
# 22793                403.9
# 19995                 38.6
# 23328                674.3
# ...                    ...
# 1266                   6.2
# ...

# %%
fidelity = pd.read_csv('fidelity_500.csv')

# %%
fidelity
# Out:
#     Symbol                Company Name Security Type  Security Price  \
# 0    BRK/A      Berkshire Hathaway Inc  Common Stock       267954.00
# 1    BRK/B      Berkshire Hathaway Inc  Common Stock          178.34
# 2     AMZN              Amazon.com Inc  Common Stock         1906.59
# 3     AAPL                   Apple Inc  Common Stock          241.41
# 4      CVS             CVS Health Corp  Common Stock           55.72
# ..     ...                         ...           ...             ...
# 495    WSM        Williams-Sonoma Inc.  Common Stock           38.19
# 496    CMC        Commercial Metals Co  Common Stock           14.63
# 497  RUSHA        Rush Enterprises Inc  Common Stock           28.93
# 498  RUSHB        Rush Enterprises Inc  Common Stock           26.50
# 499   AMTD  TD AMERITRADE Holding Corp  Common Stock           34.81
#
#     Market Capitalization  Revenue (TTM)                  Sector  \
# 0                      --     327223.000              Financials
# ...
